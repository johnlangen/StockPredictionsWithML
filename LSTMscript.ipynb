# %% [markdown]
# # This script gets 5 accuracies for each stock, by training the LSTM 5 different times per stock and making the predictions
# * accuracy is computed by seeing how the trading algorithm would performed over different time intervals (1 and 2 yrs) compared to how you would do if you just bought and held the stock, full analysis in stocks.LSTM

# %%
import pandas as pd
import numpy as np
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.layers import Bidirectional


sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

yf.pdr_override()


tech_list = ['TSLA', 'AAPL', 'GE', 'MARA', 'SRPT', 'ABR', 'MSFT', 'AMZN', 'JPM', 'NVDA', 'JNJ', 'IBM', 'KO', 'VZ', 'WMT', 'JPM', 'PG', 'CVX', 'PEP', 'MMM', 'XOM', 'BA', 'CSCO', 'INTC', 'RTX', 'CAT', 'GS', 'HD', 'NKE', 'DIS']


for stock_symbol in tech_list:
    print(stock_symbol)
    print("\n")
    # Set up End and Start times for data grab
    end = datetime.now()
    start = datetime(end.year - 1, end.month, end.day)

    # Get stock data
    stock_data = yf.download(stock_symbol, start, end)


    for i in range(5):
        # get stock quote, specify start date ****
        df = pdr.get_data_yahoo(stock_symbol, start='2014-04-01', end=datetime.now())

        # create a dataframe with close
        data = df.filter(['Close'])

        # convert dataframe to numpy array
        dataset = data.values

        # get the # of rows to train the model on, how much to save for validation ***

        # 2014-04-01, and .89
        training_data_len = int(np.ceil( len(dataset) * .89 ))

        # scale the data
        scaler = MinMaxScaler(feature_range=(0,1))
        scaled_data = scaler.fit_transform(dataset)

        # create the training data set 
        train_data = scaled_data[0:int(training_data_len), :]

        # split the data into x_train and y_train data sets
        x_train = []
        y_train = []

        for i in range(60, len(train_data)):
            x_train.append(train_data[i-60:i, 0])
            y_train.append(train_data[i, 0])

        # convert x_train and y_train to numpy arrays 
        x_train, y_train = np.array(x_train), np.array(y_train)

        # reshape the data
        x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

        # build the Bidirectional LSTM model
        model = Sequential()
        model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(x_train.shape[1], 1)))
        model.add(Bidirectional(LSTM(64, return_sequences=False)))
        model.add(Dense(25))
        model.add(Dense(1))

        # compile the model
        model.compile(optimizer='adam', loss='mean_squared_error')

        # train the model
        model.fit(x_train, y_train, batch_size=1, epochs=1)

        # create a new array containing scaled values from index 1543 to 2002 
        test_data = scaled_data[training_data_len - 60: , :]

        # create the data sets x_test and y_test
        x_test = []
        y_test = dataset[training_data_len:, :]
        for i in range(60, len(test_data)):
            x_test.append(test_data[i-60:i, 0])

        # convert the data to a numpy array
        x_test = np.array(x_test)

        # reshape the data
        x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

        # get the models predicted price values 
        predictions = model.predict(x_test)
        predictions = scaler.inverse_transform(predictions)

        # get the root mean squared error (RMSE)
        rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))


        # plot the data
        train = data[:training_data_len]
        valid = data[training_data_len:].copy()
        valid['Predictions'] = predictions

        # visualize the data
        plt.figure(figsize=(16,6))
        plt.title('Model')
        plt.xlabel('Date', fontsize=18)
        plt.ylabel('Close Price USD ($)', fontsize=18)
        plt.plot(train['Close'])
        plt.plot(valid[['Close', 'Predictions']])
        plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')

        actualClose = valid['Close']
        predictedClose = valid['Predictions']
        actualPercentChange = valid['Close'].pct_change()
        predictedPercentChange = valid['Predictions'].pct_change()

        initial_investment = 100
        capital = initial_investment
        position = 0

        data = {'Date': [], 'Action': [], 'Investment': [], 'Buy & Hold': [], 'Actual Close': [], 'Predicted Close': []}

        for i in range(len(predictedClose) - 1):
            if predictedClose[i] <= predictedClose[i + 1] and position == 0:
                position = capital / actualClose[i]
                capital = 0
                action = "Buy"
            elif predictedClose[i] >= predictedClose[i + 1] and position > 0:
                capital = position * actualClose[i]
                position = 0
                action = "Sell"
            else:
                action = "Hold"

            total_investment = capital + (position * actualClose[i])
            buy_and_hold = initial_investment * (actualClose[i] / actualClose[0])

            data['Date'].append(actualClose.index[i])
            data['Action'].append(action)
            data['Investment'].append(round(total_investment, 2))
            data['Buy & Hold'].append(round(buy_and_hold, 2))
            data['Actual Close'].append(round(actualClose[i], 2))
            data['Predicted Close'].append(round(predictedClose[i], 2))

        results_df = pd.DataFrame(data)

        # Apply formatting to the DataFrame
        styled_results_df = results_df.style.format({'Date': '{:%Y-%m-%d}',
                                                     'Investment': '{:.2f}',
                                                     'Buy & Hold': '{:.2f}',
                                                     'Actual Close': '{:.2f}',
                                                     'Predicted Close': '{:.2f}'})


        final_investment = results_df.iloc[-1]['Investment']
        final_buy_and_hold = results_df.iloc[-1]['Buy & Hold']

        print(f"Final Investment: {final_investment:.2f}")
        print(f"Final Buy & Hold: {final_buy_and_hold:.2f}")
# Out:
# TSLA
#
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 75
#      73 model = Sequential()
#      74 model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(x_train.shape[1], 1)))
# ---> 75 model.add(Bidirectional(LSTM(64, return_sequences=False)))
#      76 model.add(Dense(25))
#      77 model.add(Dense(1))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/sequential.py:234, in Sequential.add(self, layer)
#     229         self._has_explicit_input_shape = True
#     231 elif self.outputs:
#     232     # If the model is being built continuously on top of an input layer:
#     233     # refresh its output.
# --> 234     output_tensor = layer(self.outputs[0])
#     235     if len(tf.nest.flatten(output_tensor)) != 1:
#     236         raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/bidirectional.py:277, in Bidirectional.__call__(self, inputs, initial_state, constants, **kwargs)
#     274     inputs = inputs[0]
#     276 if initial_state is None and constants is None:
# --> 277     return super().__call__(inputs, **kwargs)
#     279 # Applies the same workaround as in `RNN.__call__`
#     280 additional_inputs = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py:1011, in Layer.__call__(self, *args, **kwargs)
#    1003 # Functional Model construction mode is invoked when `Layer`s are called
#    1004 # on symbolic `KerasTensor`s, i.e.:
#    1005 # >> inputs = tf.keras.Input(10)
#    1006 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1007 # >> model = tf.keras.Model(inputs, outputs)
#    1008 if _in_functional_construction_mode(
#    1009     self, inputs, args, kwargs, input_list
#    1010 ):
# -> 1011     return self._functional_construction_call(
#    1012         inputs, args, kwargs, input_list
#    1013     )
#    1015 # Maintains info about the `Layer.call` stack.
#    1016 call_context = base_layer_utils.call_context()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py:2498, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    2491         training_arg_passed_by_framework = True
#    2493 with call_context.enter(
#    2494     layer=self, inputs=inputs, build_graph=True, training=training_value
#    2495 ):
#    2496     # Check input assumptions set after layer building, e.g. input
#    2497     # shape.
# -> 2498     outputs = self._keras_tensor_symbolic_call(
#    2499         inputs, input_masks, args, kwargs
#    2500     )
#    2502     if outputs is None:
#    2503         raise ValueError(
#    2504             "A layer's `call` method should return a "
#    2505             "Tensor or a list of Tensors, not None "
#    2506             "(layer: " + self.name + ")."
#    2507         )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py:2345, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2341     return tf.nest.map_structure(
#    2342         keras_tensor.KerasTensor, output_signature
#    2343     )
#    2344 else:
# -> 2345     return self._infer_output_signature(
#    2346         inputs, args, kwargs, input_masks
#    2347     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py:2404, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2402         self._maybe_build(inputs)
#    2403         inputs = self._maybe_cast_inputs(inputs)
# -> 2404         outputs = call_fn(inputs, *args, **kwargs)
#    2406     self._handle_activity_regularization(inputs, outputs)
#    2407 self._set_mask_metadata(
#    2408     inputs, outputs, input_masks, build_graph=False
#    2409 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/bidirectional.py:407, in Bidirectional.call(self, inputs, training, mask, initial_state, constants)
#     402         forward_state, backward_state = None, None
#     404     y = self.forward_layer(
#     405         forward_inputs, initial_state=forward_state, **kwargs
#     406     )
# --> 407     y_rev = self.backward_layer(
#     408         backward_inputs, initial_state=backward_state, **kwargs
#     409     )
#     410 else:
#     411     y = self.forward_layer(inputs, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/base_rnn.py:553, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     548 inputs, initial_state, constants = rnn_utils.standardize_args(
#     549     inputs, initial_state, constants, self._num_constants
#     550 )
#     552 if initial_state is None and constants is None:
# --> 553     return super().__call__(inputs, **kwargs)
#     555 # If any of `initial_state` or `constants` are specified and are Keras
#     556 # tensors, then add them to the inputs and temporarily modify the
#     557 # input_spec to include them.
#     559 additional_inputs = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/lstm.py:751, in LSTM.call(self, inputs, mask, training, initial_state)
#     737                 (
#     738                     last_output,
#     739                     outputs,
#    (...)
#     742                     runtime,
#     743                 ) = standard_lstm(**normal_lstm_kwargs)
#     744         else:
#     745             (
#     746                 last_output,
#     747                 outputs,
#     748                 new_h,
#     749                 new_c,
#     750                 runtime,
# --> 751             ) = lstm_with_backend_selection(**normal_lstm_kwargs)
#     753     states = [new_h, new_c]
#     755 if self.stateful:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/lstm.py:1356, in lstm_with_backend_selection(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask, return_sequences)
#    1351     # Call the normal LSTM impl and register the cuDNN impl function. The
#    1352     # grappler will kick in during session execution to optimize the graph.
#    1353     last_output, outputs, new_h, new_c, runtime = defun_standard_lstm(
#    1354         **params
#    1355     )
# -> 1356     gru_lstm_utils.function_register(defun_gpu_lstm, **params)
#    1358 return last_output, outputs, new_h, new_c, runtime
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/gru_lstm_utils.py:257, in function_register(func, *args, **kwargs)
#     238 def function_register(func, *args, **kwargs):
#     239     """Register a specialization of a `Function` into the graph.
#     240
#     241     This won't actually call the function with the inputs, and only put the
#    (...)
#     255         function.
#     256     """
# --> 257     concrete_func = func.get_concrete_function(*args, **kwargs)
#     258     concrete_func.add_to_graph()
#     259     concrete_func.add_gradient_functions_to_graph()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2610, in Function.get_concrete_function(self, *args, **kwargs)
#    2601 def get_concrete_function(self, *args, **kwargs):
#    2602   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    2603
#    2604   Args:
#    (...)
#    2608        or `tf.Tensor` or `tf.TensorSpec`.
#    2609   """
# -> 2610   graph_function = self._get_concrete_function_garbage_collected(
#    2611       *args, **kwargs)
#    2612   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    2613   return graph_function
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2576, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2574   args, kwargs = None, None
#    2575 with self._lock:
# -> 2576   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2577   seen_names = set()
#    2578   captured = object_identity.ObjectIdentitySet(
#    2579       graph_function.graph.internal_captures)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2760, in Function._maybe_define_function(self, args, kwargs)
#    2758   # Only get placeholders for arguments, not captures
#    2759   args, kwargs = placeholder_dict["args"]
# -> 2760 graph_function = self._create_graph_function(args, kwargs)
#    2762 graph_capture_container = graph_function.graph._capture_func_lib  # pylint: disable=protected-access
#    2763 # Maintain the list of all captures
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2670, in Function._create_graph_function(self, args, kwargs)
#    2665 missing_arg_names = [
#    2666     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2667 ]
#    2668 arg_names = base_arg_names + missing_arg_names
#    2669 graph_function = ConcreteFunction(
# -> 2670     func_graph_module.func_graph_from_py_func(
#    2671         self._name,
#    2672         self._python_function,
#    2673         args,
#    2674         kwargs,
#    2675         self.input_signature,
#    2676         autograph=self._autograph,
#    2677         autograph_options=self._autograph_options,
#    2678         arg_names=arg_names,
#    2679         capture_by_value=self._capture_by_value),
#    2680     self._function_attributes,
#    2681     spec=self.function_spec,
#    2682     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2683     # scope. This is not the default behavior since it gets used in some
#    2684     # places (like Keras) where the FuncGraph lives longer than the
#    2685     # ConcreteFunction.
#    2686     shared_func_graph=False)
#    2687 return graph_function
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py:1247, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1244 else:
#    1245   _, original_func = tf_decorator.unwrap(python_func)
# -> 1247 func_outputs = python_func(*func_args, **func_kwargs)
#    1249 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1250 # TensorArrays and `None`s.
#    1251 func_outputs = nest.map_structure(
#    1252     convert, func_outputs, expand_composites=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/lstm.py:1260, in lstm_with_backend_selection.<locals>.gpu_lstm_with_fallback(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask, return_sequences)
#    1258 """Use cuDNN kernel when mask is none or strictly right padded."""
#    1259 if mask is None:
# -> 1260     return gpu_lstm(
#    1261         inputs=inputs,
#    1262         init_h=init_h,
#    1263         init_c=init_c,
#    1264         kernel=kernel,
#    1265         recurrent_kernel=recurrent_kernel,
#    1266         bias=bias,
#    1267         mask=mask,
#    1268         time_major=time_major,
#    1269         go_backwards=go_backwards,
#    1270         sequence_lengths=sequence_lengths,
#    1271         return_sequences=return_sequences,
#    1272     )
#    1274 def cudnn_lstm_fn():
#    1275     return gpu_lstm(
#    1276         inputs=inputs,
#    1277         init_h=init_h,
#    (...)
#    1286         return_sequences=return_sequences,
#    1287     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/keras/layers/rnn/lstm.py:1166, in gpu_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, return_sequences)
#    1164 # Match CPU return format
#    1165 if not return_sequences:
# -> 1166     outputs = tf.expand_dims(last_output, axis=0 if time_major else 1)
#    1168 return (
#    1169     last_output,
#    1170     outputs,
#    (...)
#    1173     gru_lstm_utils.runtime(gru_lstm_utils.RUNTIME_GPU),
#    1174 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:442, in expand_dims_v2(input, axis, name)
#     375 @tf_export("expand_dims", v1=[])
#     376 @dispatch.add_dispatch_support
#     377 def expand_dims_v2(input, axis, name=None):
#     378   """Returns a tensor with a length 1 axis inserted at index `axis`.
#     379
#     380   Given a tensor `input`, this operation inserts a dimension of length 1 at the
#    (...)
#     440     InvalidArgumentError: If `axis` is out of range `[-(D+1), D]`.
#     441   """
# --> 442   return gen_array_ops.expand_dims(input, axis, name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:2358, in expand_dims(input, axis, name)
#    2356     pass  # Add nodes to the TensorFlow graph.
#    2357 # Add nodes to the TensorFlow graph.
# -> 2358 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    2359       "ExpandDims", input=input, dim=axis, name=name)
#    2360 _result = _outputs[:]
#    2361 if _execute.must_record_gradient():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py:779, in _apply_op_helper(op_type_name, name, **keywords)
#     777 with g.as_default(), ops.name_scope(name) as scope:
#     778   if fallback:
# --> 779     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     780                            keywords, default_type_attr_map, attrs, inputs,
#     781                            input_types)
#     782     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     783                            default_type_attr_map, attrs)
#     784     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py:532, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     530 inferred = None
#     531 try:
# --> 532   inferred = ops.convert_to_tensor(
#     533       values, name=input_arg.name, as_ref=input_arg.is_ref)
#     534 except TypeError as err:
#     535   # When converting a python object such as a list of Dimensions, we
#     536   # need a dtype to be specified, thus tensor conversion may throw
#     537   # an exception which we will ignore and try again below.
#     538   pass
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1615, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1612 if overload is not None:
#    1613   return overload(value, dtype, name)  #  pylint: disable=not-callable
# -> 1615 for base_type, conversion_func in tensor_conversion_registry.get(type(value)):
#    1616   # If dtype is None but preferred_dtype is not None, we try to
#    1617   # cast to preferred_dtype first.
#    1618   ret = None
#    1619   if dtype is None and preferred_dtype is not None:
#
# KeyboardInterrupt:
